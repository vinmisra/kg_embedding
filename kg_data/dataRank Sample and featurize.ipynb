# %% [markdown]
# #this notebook handles the python side of sampling positive and negative cases for model training.
# ###Results are of the form (A,At,B,Bt,reltype)
# ###Results are fed to DB2, which generates feature data for each sample.

# %%
import jaydebeapi
import jpype

# %%
# %matplotlib inline
import pandas
import os
import numpy
from ordereddict import OrderedDict
from ggplot import *
import re

# %%
jar = '/gsa/yktgsa/home/v/m/vmisra/kg/lib/db2jcc4-10.5.0.4-2.95.0-SNAPSHOT.jar'
args='-Djava.class.path=%s' % jar
jvm = jpype.getDefaultJVMPath()
jpype.startJVM(jvm, args)

# %%
conn = jaydebeapi.connect('com.ibm.db2.jcc.DB2Driver',['jdbc:db2://kg.almaden.ibm.com:50000/KG_R229','db2inst1','perfload!'])
curs = conn.cursor()

# %%
conn = jaydebeapi.connect('com.ibm.db2.jcc.DB2Driver',['jdbc:db2://wd-app03.swg.usma.ibm.com:50000/KG_R231','db2inst1','Pa88w0rd'])
curs = conn.cursor()

# %%
#quick test of the connection
N_ENTRIES = 10
sql = 'select "subject/instanceName_up", "subject/typeType","object/instanceName_up","object/typeType"'
sql = sql + ' from ADS."SIRE1.1"'
sql = sql + ' fetch first %(N_ENTRIES)i rows only' % {'N_ENTRIES':N_ENTRIES}
print sql
curs.execute(sql)
out = curs.fetchall()
print out[:1000]
# Out:
# select "subject/instanceName_up", "subject/typeType","object/instanceName_up","object/typeType" from ADS."SIRE1.1" fetch first 10 rows only
# [(u'ISLANDS', u'GEOLOGICALOBJ', u'SEA', u'GEOLOGICALOBJ'), (u'JUDGES', u'PEOPLE', u'APPOINTED', u'EVENT_PERSONNEL'), (u'JUDGES', u'PEOPLE', u'HIGH COURT', u'ORGANIZATION'), (u'JUDICIAL AND LEGAL SERVICES COMMISSION', u'ORGANIZATION', u'APPOINTED', u'EVENT_PERSONNEL'), (u'JUSTICES', u'PEOPLE', u'COURT OF APPEAL', u'ORGANIZATION'), (u'LEADERS', u'PEOPLE', u'ANGUILLA', u'GPE'), (u'LEADERS', u'PEOPLE', u'WORLD', u'GPE'), (u'LEEWARD ISLANDS', u'GEOLOGICALOBJ', u'LESSER ANTILLES', u'LOCATION'), (u'LEGISLATIVE BRANCH', u'ORGANIZATION', u'ANGUILLA', u'GPE'), (u'LEGISLATIVE BRANCH', u'ORGANIZATION', u'NATIONAL ANTHEM OF ANGUILLA', u'ORGANIZATION')]

# %% [markdown]
# ##Load relations from DB2

# %%
#constants for loading the data
MIN_MENTIONS=2
DB_V = '235'
dump_path = '/home/db2inst1/vinith/dump_v%(db_v)s_minmentions%(min_mentions)s.del' %{"db_v":DB_V,"min_mentions":MIN_MENTIONS}
sql = '''
connect to KG_R%(db_v)s;
export to %(dump_path)s of del
SELECT * FROM
(Select 
    "subject/instanceName_up",
    "subject/typeType",
    "object/instanceName_up",
    "object/typeType",
    "relCanonicalName",
    SUM("mAB_doc") as "mAB",
    count(*) as "n_docs"
from (
     Select
        "subject/instanceName_up",
        "subject/typeType",
        "object/instanceName_up",
        "object/typeType",
        "relCanonicalName",
        "documentID",
        count(*) as "mAB_doc"
     from 
     (select * from ADS."SIRE1.1"
     fetch first %(row_limit)i rows only)
     group by ( "subject/instanceName_up",
                "subject/typeType",
                "object/instanceName_up",
                "object/typeType",
                "relCanonicalName",
                "documentID"
              )
     )
group by (  "subject/instanceName_up",
            "subject/typeType",
            "object/instanceName_up",
            "object/typeType",
            "relCanonicalName"
         )
)
Where "mAB" > %(min_mab)i;''' % {"db_v":DB_V,"dump_path": dump_path, "min_mab": MIN_MENTIONS-1, "row_limit": 300000000}

print sql
# Out:
# connect to KG_R235;
# export to /home/db2inst1/vinith/dump_v235_minmentions2.del of del
# SELECT * FROM
# (Select
#     "subject/instanceName_up",
#     "subject/typeType",
#     "object/instanceName_up",
#     "object/typeType",
#     "relCanonicalName",
#     SUM("mAB_doc") as "mAB",
#     count(*) as "n_docs"
# from (
#      Select
#         "subject/instanceName_up",
#         "subject/typeType",
#         "object/instanceName_up",
#         "object/typeType",
#         "relCanonicalName",
#         "documentID",
#         count(*) as "mAB_doc"
#      from
#      (select * from ADS."SIRE1.1"
#      fetch first 300000000 rows only)
#      group by ( "subject/instanceName_up",
#                 "subject/typeType",
#                 "object/instanceName_up",
#                 "object/typeType",
#                 "relCanonicalName",
#                 "documentID"
#               )
#      )
# group by (  "subject/instanceName_up",
#             "subject/typeType",
#             "object/instanceName_up",
#             "object/typeType",
#             "relCanonicalName"
#          )
# )
# Where "mAB" > 1;

# %% [markdown]
# ###Run the above SQL in db2 on wd-app03.
# ###Then, copy over the file to the path: local_path_reltable

# %% [markdown]
# ##Load Entity data from DB2

# %%
#creating vintitystats (custom version of ads.entitystats2)
sql = '''
drop table vintitystats;
create table vintitystats
    ("subject/instanceName_up" varchar(128), "subject/typeType" varchar(128), "RELATIONSHIPMENTIONCOUNT" varchar(128), "DOCUMENTCOUNT" varchar(128));

insert into vintitystats
    ("subject/instanceName_up", "subject/typeType", "RELATIONSHIPMENTIONCOUNT", "DOCUMENTCOUNT")
Select * from (
    Select "subject/instanceName_up", "subject/typeType", SUM("mA") as "RELATIONSHIPMENTIONCOUNT", COUNT("documentID") as "DOCUMENTCOUNT"
    from (
        SELECT "subject/instanceName_up", "subject/typeType", COUNT(*) as "mA", "documentID"
        from ADS."SIRE1.1"
        group by "subject/instanceName_up", "subject/typeType", "documentID"
        )
    group by "subject/instanceName_up", "subject/typeType"
    ); '''
print sql
# Out:
# drop table vintitystats;
# create table vintitystats
#     ("subject/instanceName_up" varchar(128), "subject/typeType" varchar(128), "RELATIONSHIPMENTIONCOUNT" varchar(128), "DOCUMENTCOUNT" varchar(128));
#
# insert into vintitystats
#     ("subject/instanceName_up", "subject/typeType", "RELATIONSHIPMENTIONCOUNT", "DOCUMENTCOUNT")
# Select * from (
#     Select "subject/instanceName_up", "subject/typeType", SUM("mA") as "RELATIONSHIPMENTIONCOUNT", COUNT("documentID") as "DOCUMENTCOUNT"
#     from (
#         SELECT "subject/instanceName_up", "subject/typeType", COUNT(*) as "mA", "documentID"
#         from ADS."SIRE1.1"
#         group by "subject/instanceName_up", "subject/typeType", "documentID"
#         )
#     group by "subject/instanceName_up", "subject/typeType"
#     );

# %%
MIN_RELCOUNT=3
MAX_RELCOUNT=1000

sql = """
export to /home/db2inst1/vinith/dump_entities_v%(db_v)s_minrelcount_%(min_relcount)i.del of del
Select * from vintitystats
where ("DOCUMENTCOUNT" > %(min_docs)i) and
("DOCUMENTCOUNT" < %(max_docs)i)
fetch first %(row_limit)i rows only;
""" % {"db_v":DB_V, "min_relcount":MIN_RELCOUNT, "row_limit":100000000, "min_docs":MIN_RELCOUNT, "max_docs":MAX_RELCOUNT}
print sql
# Out:
# export to /home/db2inst1/vinith/dump_entities_v235_minrelcount_3.del of del
# Select * from vintitystats
# where ("DOCUMENTCOUNT" > 3) and
# ("DOCUMENTCOUNT" < 1000)
# fetch first 100000000 rows only;

# %% [markdown]
# ###Run the above SQL on wd-app03
# ###Copy over file to local_path_entitytable

# %% [markdown]
# ##load both tables into pandas

# %%
relcols = ['A',
           'At',
           'B',
           'Bt',
           'reltype',
           'mAB',
           'nDocs']
local_path_reltable = '/ceph/vinith/kg/dump_rel.del'
reldata = pandas.read_csv(local_path_reltable,header=None,names=relcols)

# %%
reldata['pattern_A']=reldata.loc[:,'A']+';'+reldata.loc[:,'At']
reldata['pattern_B']=reldata.loc[:,'B']+';'+reldata.loc[:,'Bt']
reldata['pattern']=reldata.loc[:,'pattern_A']+';'+reldata.loc[:,'pattern_B']

# %%
#for MQT dump, which we are not currently using. Using manually generated table instead.
#entitycols = ['A','At','SomeCrap','nDocs','relcount','neighbors','relcount_distinct']
entitycols = ['A',
              'At',
              'relcount',
             'nDocs']
local_path_entitytable = '/ceph/vinith/kg/dump_entities.del'
entitydata = pandas.read_csv(local_path_entitytable,header=None,names=entitycols)
#entitydata = entitydata.drop('SomeCrap',1) #removing unnecessary info from MQT dump

# %% [markdown]
# ##Positive Sampling

# %% [markdown]
# Idea: randomly sample significant relationships between significant entities

# %%
reldata=pandas.merge(reldata,
                                 entitydata,
                                 left_on=['A','At'],
                                 right_on=['A','At'],
                                 suffixes=['','_A'])
reldata
# Out:
#                              A      At                            B  \
# 0                   " AMARANTE  PERSON                     PORTUGAL
# 1                     " ASIMOV  PERSON                      FICTION
# 2                     " ASTANA  PERSON                   KAZAKHSTAN
# 3                    " BANGKOK  PERSON                     THAILAND
# 4                    " BANGKOK  PERSON                      SINGLES
# 5                        " BEL  PERSON                           VL
# 6                        " BEL  PERSON                           WA
# 7                   " BOTTOM 3  PERSON                      COUPLES
# 8                    " BUKHARA  PERSON                   UZBEKISTAN
# 9                       " ELIM  PERSON                     #FBF373"
# 10                   " EVICTED  PERSON                       DAY 29
# 11                   " EVICTED  PERSON                        DAY 8
# 12                   " EVICTED  PERSON                        DAY 9
# 13                   " EVICTED  PERSON                        HOUSE
# 14                  " GARFIELD  PERSON                      FRIENDS
# 15                 " HERAKLION  PERSON                      SINGLES
# 16                     " JAPAN  PERSON                       ORICON
# 17                   " JOHNSON  PERSON                        CANDY
# 18                   " JOHNSON  PERSON                GUITAR JUNIOR
# 19                   " JOHNSON  PERSON                     THE ROCK
# 20                    " KAARST  PERSON                      GERMANY
# 21                    " LEGION  PERSON                        MERIT
# 22                      " LUCY  PERSON                          SKY
# 23                   " MASKAEV  PERSON                    THE BIG O
# 24                  " MASSERIA  PERSON                     BROOKLYN
# 25                  " MASSERIA  PERSON          CASTELLAMMARESE WAR
# 26                  " MASSERIA  PERSON                      ITALIAN
# 27                  " MASSERIA  PERSON                LUCKY LUCIANO
# 28                  " MASSERIA  PERSON          SALVATORE MARANZANO
# 29                  " MASSERIA  PERSON                VITO GENOVESE
# ...                        ...     ...                          ...
# 2865322                _SLO00A  PERSON                   PATTERN_SH
# 2865323          _SOUNDERS_10T  PERSON                   PATTERN_SH
# 2865324          _SOUNDERS_11A  PERSON                   PATTERN_SH
# 2865325       _STRICON_ONWHITE  PERSON                   PATTERN_SH
# 2865326         _STRICON_WHITE  PERSON                   PATTERN_SH
# 2865327        _STRICON_WHITE2  PERSON                   PATTERN_SH
# 2865328     _STRIPES_CUT_BLACK  PERSON                   PATTERN_SH
# 2865329     _STRIPES_CUT_WHITE  PERSON                   PATTERN_R1
# 2865330     _STRIPES_CUT_WHITE  PERSON                   PATTERN_SH
# 2865331                _SUI10H  PERSON                   PATTERN_SH
# 2865332                _SWEH06  PERSON                   PATTERN_SH
# 2865333              _TEREK11H  PERSON                   PATTERN_SH
# 2865334               _TFC_11H  PERSON                   PATTERN_SH
# 2865335           _TIGRES1011H  PERSON                   PATTERN_SH
# 2865336           _TIMBERS_13H  PERSON                   PATTERN_SH
# 2865337              _TOP_BLUE  PERSON                _WHITE_COLLAR
# 2865338        _TROFEO_ONWHITE  PERSON                   PATTERN_SH
# 2865339          _TROFEO_WHITE  PERSON                   PATTERN_SH
# 2865340                _URU10H  PERSON                   PATTERN_SH
# 2865341                _USA10H  PERSON                   PATTERN_SH
# 2865342         _WHITECAPS_13H  PERSON                   PATTERN_SH
# 2865343          _WHITE_BORDER  PERSON                   PATTERN_SH
# 2865344         _WHITE_STRIPES  PERSON   _WHITE_STRIPES PATTERN_SH1
# 2865345         _WHITE_STRIPES  PERSON   _WHITE_STRIPES PATTERN_SH2
# 2865346         _WHITE_STRIPES  PERSON   _WHITE_STRIPES PATTERN_SO1
# 2865347        _WHITE_STRIPES2  PERSON  _WHITE_STRIPES2 PATTERN_SH1
# 2865348  _WHITE_STRIPES_ADIDAS  PERSON                   PATTERN_SH
# 2865349          _ZAMALEK1213H  PERSON                   PATTERN_SH
# 2865350            _ZENIT1112A  PERSON       _ZENIT1112H PATTERN_SO
# 2865351              __NOTOC__  PERSON                     JAPANESE
#
#                    Bt        reltype  mAB  nDocs  \
# 0                 GPE      locatedAt    4      4
# 1           TITLEWORK       authorOf    6      4
# 2                 GPE      locatedAt    6      6
# 3                 GPE      locatedAt    6      6
# 4        EVENT_SPORTS  participantIn    5      5
# 5        ORGANIZATION     employedBy   12     12
# 6        ORGANIZATION     employedBy   18     18
# 7              PEOPLE     partOfMany    6      6
# 8                 GPE      locatedAt    4      4
# 9              PERSON     colocation    4      4
# 10               DATE         bornOn    5      5
# 11               DATE         bornOn    8      8
# 12               DATE         bornOn    4      4
# 13       ORGANIZATION     colocation    6      6
# 14             PEOPLE     partOfMany    4      4
# 15       EVENT_SPORTS  participantIn    6      6
# 16       ORGANIZATION     employedBy    5      5
# 17          TITLEWORK       authorOf    4      4
# 18          TITLEWORK       authorOf    5      4
# 19          TITLEWORK       authorOf    6      6
# 20                GPE      locatedAt    4      4
# 21       ORGANIZATION     employedBy    4      4
# 22       ORGANIZATION     employedBy    5      5
# 23          TITLEWORK       authorOf    5      5
# 24                GPE     colocation    4      4
# 25             PERSON     colocation    6      5
# 26                GPE     colocation    4      4
# 27             PERSON     colocation    4      3
# 28             PERSON     colocation   11      8
# 29             PERSON     colocation    5      4
# ...               ...            ...  ...    ...
# 2865322        PERSON     colocation    4      4
# 2865323        PERSON     colocation    4      4
# 2865324        PERSON     colocation    4      4
# 2865325        PERSON     colocation   17     17
# 2865326        PERSON     colocation   17     17
# 2865327        PERSON     colocation    7      7
# 2865328        PERSON     colocation    5      5
# 2865329        PERSON     colocation    4      4
# 2865330        PERSON     colocation    4      4
# 2865331        PERSON     colocation    5      5
# 2865332        PERSON     colocation    5      5
# 2865333        PERSON     colocation    4      4
# 2865334        PERSON     colocation    4      4
# 2865335        PERSON     colocation    4      4
# 2865336        PERSON     colocation    4      4
# 2865337        PERSON     colocation    7      7
# 2865338        PERSON     colocation    4      4
# 2865339        PERSON     colocation    6      6
# 2865340        PERSON     colocation    4      4
# 2865341        PERSON     colocation   14     14
# 2865342        PERSON     colocation    5      5
# 2865343        PERSON     colocation    5      5
# 2865344       PRODUCT     colocation    6      6
# 2865345       PRODUCT     colocation    4      4
# 2865346       PRODUCT     colocation    4      4
# 2865347       PRODUCT     colocation    5      5
# 2865348        PERSON     colocation    4      4
# 2865349        PERSON     colocation    4      4
# 2865350        PERSON     colocation    4      4
# 2865351           GPE     partOfMany    4      4
#
#                             pattern_A                            pattern_B  \
# 0                   " AMARANTE;PERSON                         PORTUGAL;GPE
# 1                     " ASIMOV;PERSON                    FICTION;TITLEWORK
# 2                     " ASTANA;PERSON                       KAZAKHSTAN;GPE
# 3                    " BANGKOK;PERSON                         THAILAND;GPE
# 4                    " BANGKOK;PERSON                 SINGLES;EVENT_SPORTS
# 5                        " BEL;PERSON                      VL;ORGANIZATION
# 6                        " BEL;PERSON                      WA;ORGANIZATION
# 7                   " BOTTOM 3;PERSON                       COUPLES;PEOPLE
# 8                    " BUKHARA;PERSON                       UZBEKISTAN;GPE
# 9                       " ELIM;PERSON                      #FBF373";PERSON
# 10                   " EVICTED;PERSON                          DAY 29;DATE
# 11                   " EVICTED;PERSON                           DAY 8;DATE
# 12                   " EVICTED;PERSON                           DAY 9;DATE
# 13                   " EVICTED;PERSON                   HOUSE;ORGANIZATION
# 14                  " GARFIELD;PERSON                       FRIENDS;PEOPLE
# 15                 " HERAKLION;PERSON                 SINGLES;EVENT_SPORTS
# 16                     " JAPAN;PERSON                  ORICON;ORGANIZATION
# 17                   " JOHNSON;PERSON                      CANDY;TITLEWORK
# 18                   " JOHNSON;PERSON              GUITAR JUNIOR;TITLEWORK
# 19                   " JOHNSON;PERSON                   THE ROCK;TITLEWORK
# 20                    " KAARST;PERSON                          GERMANY;GPE
# 21                    " LEGION;PERSON                   MERIT;ORGANIZATION
# 22                      " LUCY;PERSON                     SKY;ORGANIZATION
# 23                   " MASKAEV;PERSON                  THE BIG O;TITLEWORK
# 24                  " MASSERIA;PERSON                         BROOKLYN;GPE
# 25                  " MASSERIA;PERSON           CASTELLAMMARESE WAR;PERSON
# 26                  " MASSERIA;PERSON                          ITALIAN;GPE
# 27                  " MASSERIA;PERSON                 LUCKY LUCIANO;PERSON
# 28                  " MASSERIA;PERSON           SALVATORE MARANZANO;PERSON
# 29                  " MASSERIA;PERSON                 VITO GENOVESE;PERSON
# ...                               ...                                  ...
# 2865322                _SLO00A;PERSON                    PATTERN_SH;PERSON
# 2865323          _SOUNDERS_10T;PERSON                    PATTERN_SH;PERSON
# 2865324          _SOUNDERS_11A;PERSON                    PATTERN_SH;PERSON
# 2865325       _STRICON_ONWHITE;PERSON                    PATTERN_SH;PERSON
# 2865326         _STRICON_WHITE;PERSON                    PATTERN_SH;PERSON
# 2865327        _STRICON_WHITE2;PERSON                    PATTERN_SH;PERSON
# 2865328     _STRIPES_CUT_BLACK;PERSON                    PATTERN_SH;PERSON
# 2865329     _STRIPES_CUT_WHITE;PERSON                    PATTERN_R1;PERSON
# 2865330     _STRIPES_CUT_WHITE;PERSON                    PATTERN_SH;PERSON
# 2865331                _SUI10H;PERSON                    PATTERN_SH;PERSON
# 2865332                _SWEH06;PERSON                    PATTERN_SH;PERSON
# 2865333              _TEREK11H;PERSON                    PATTERN_SH;PERSON
# 2865334               _TFC_11H;PERSON                    PATTERN_SH;PERSON
# 2865335           _TIGRES1011H;PERSON                    PATTERN_SH;PERSON
# 2865336           _TIMBERS_13H;PERSON                    PATTERN_SH;PERSON
# 2865337              _TOP_BLUE;PERSON                 _WHITE_COLLAR;PERSON
# 2865338        _TROFEO_ONWHITE;PERSON                    PATTERN_SH;PERSON
# 2865339          _TROFEO_WHITE;PERSON                    PATTERN_SH;PERSON
# 2865340                _URU10H;PERSON                    PATTERN_SH;PERSON
# 2865341                _USA10H;PERSON                    PATTERN_SH;PERSON
# 2865342         _WHITECAPS_13H;PERSON                    PATTERN_SH;PERSON
# 2865343          _WHITE_BORDER;PERSON                    PATTERN_SH;PERSON
# 2865344         _WHITE_STRIPES;PERSON   _WHITE_STRIPES PATTERN_SH1;PRODUCT
# 2865345         _WHITE_STRIPES;PERSON   _WHITE_STRIPES PATTERN_SH2;PRODUCT
# 2865346         _WHITE_STRIPES;PERSON   _WHITE_STRIPES PATTERN_SO1;PRODUCT
# 2865347        _WHITE_STRIPES2;PERSON  _WHITE_STRIPES2 PATTERN_SH1;PRODUCT
# 2865348  _WHITE_STRIPES_ADIDAS;PERSON                    PATTERN_SH;PERSON
# 2865349          _ZAMALEK1213H;PERSON                    PATTERN_SH;PERSON
# 2865350            _ZENIT1112A;PERSON        _ZENIT1112H PATTERN_SO;PERSON
# 2865351              __NOTOC__;PERSON                         JAPANESE;GPE
#
#                                                    pattern  relcount  nDocs_A
# 0                           " AMARANTE;PERSON;PORTUGAL;GPE         4        4
# 1                        " ASIMOV;PERSON;FICTION;TITLEWORK        18        6
# 2                           " ASTANA;PERSON;KAZAKHSTAN;GPE        10        8
# 3                            " BANGKOK;PERSON;THAILAND;GPE        11        6
# 4                    " BANGKOK;PERSON;SINGLES;EVENT_SPORTS        11        6
# 5                             " BEL;PERSON;VL;ORGANIZATION        35       30
# 6                             " BEL;PERSON;WA;ORGANIZATION        35       30
# 7                         " BOTTOM 3;PERSON;COUPLES;PEOPLE         6        6
# 8                          " BUKHARA;PERSON;UZBEKISTAN;GPE         4        4
# 9                            " ELIM;PERSON;#FBF373";PERSON        15        7
# 10                            " EVICTED;PERSON;DAY 29;DATE       392       43
# 11                             " EVICTED;PERSON;DAY 8;DATE       392       43
# 12                             " EVICTED;PERSON;DAY 9;DATE       392       43
# 13                     " EVICTED;PERSON;HOUSE;ORGANIZATION       392       43
# 14                        " GARFIELD;PERSON;FRIENDS;PEOPLE         4        4
# 15                 " HERAKLION;PERSON;SINGLES;EVENT_SPORTS         8        6
# 16                      " JAPAN;PERSON;ORICON;ORGANIZATION         8        8
# 17                        " JOHNSON;PERSON;CANDY;TITLEWORK       169       76
# 18                " JOHNSON;PERSON;GUITAR JUNIOR;TITLEWORK       169       76
# 19                     " JOHNSON;PERSON;THE ROCK;TITLEWORK       169       76
# 20                             " KAARST;PERSON;GERMANY;GPE         4        4
# 21                      " LEGION;PERSON;MERIT;ORGANIZATION        11       10
# 22                          " LUCY;PERSON;SKY;ORGANIZATION        19        8
# 23                    " MASKAEV;PERSON;THE BIG O;TITLEWORK         6        6
# 24                          " MASSERIA;PERSON;BROOKLYN;GPE       178       13
# 25            " MASSERIA;PERSON;CASTELLAMMARESE WAR;PERSON       178       13
# 26                           " MASSERIA;PERSON;ITALIAN;GPE       178       13
# 27                  " MASSERIA;PERSON;LUCKY LUCIANO;PERSON       178       13
# 28            " MASSERIA;PERSON;SALVATORE MARANZANO;PERSON       178       13
# 29                  " MASSERIA;PERSON;VITO GENOVESE;PERSON       178       13
# ...                                                    ...       ...      ...
# 2865322                   _SLO00A;PERSON;PATTERN_SH;PERSON         4        4
# 2865323             _SOUNDERS_10T;PERSON;PATTERN_SH;PERSON         4        4
# 2865324             _SOUNDERS_11A;PERSON;PATTERN_SH;PERSON         4        4
# 2865325          _STRICON_ONWHITE;PERSON;PATTERN_SH;PERSON        17       17
# 2865326            _STRICON_WHITE;PERSON;PATTERN_SH;PERSON        17       17
# 2865327           _STRICON_WHITE2;PERSON;PATTERN_SH;PERSON         7        7
# 2865328        _STRIPES_CUT_BLACK;PERSON;PATTERN_SH;PERSON         5        5
# 2865329        _STRIPES_CUT_WHITE;PERSON;PATTERN_R1;PERSON        10       10
# 2865330        _STRIPES_CUT_WHITE;PERSON;PATTERN_SH;PERSON        10       10
# 2865331                   _SUI10H;PERSON;PATTERN_SH;PERSON         5        5
# 2865332                   _SWEH06;PERSON;PATTERN_SH;PERSON         5        5
# 2865333                 _TEREK11H;PERSON;PATTERN_SH;PERSON         4        4
# 2865334                  _TFC_11H;PERSON;PATTERN_SH;PERSON         4        4
# 2865335              _TIGRES1011H;PERSON;PATTERN_SH;PERSON         4        4
# 2865336              _TIMBERS_13H;PERSON;PATTERN_SH;PERSON         4        4
# 2865337              _TOP_BLUE;PERSON;_WHITE_COLLAR;PERSON         7        7
# 2865338           _TROFEO_ONWHITE;PERSON;PATTERN_SH;PERSON         4        4
# 2865339             _TROFEO_WHITE;PERSON;PATTERN_SH;PERSON         6        6
# 2865340                   _URU10H;PERSON;PATTERN_SH;PERSON         4        4
# 2865341                   _USA10H;PERSON;PATTERN_SH;PERSON        15       15
# 2865342            _WHITECAPS_13H;PERSON;PATTERN_SH;PERSON         5        5
# 2865343             _WHITE_BORDER;PERSON;PATTERN_SH;PERSON         7        7
# 2865344  _WHITE_STRIPES;PERSON;_WHITE_STRIPES PATTERN_S...        26       22
# 2865345  _WHITE_STRIPES;PERSON;_WHITE_STRIPES PATTERN_S...        26       22
# 2865346  _WHITE_STRIPES;PERSON;_WHITE_STRIPES PATTERN_S...        26       22
# 2865347  _WHITE_STRIPES2;PERSON;_WHITE_STRIPES2 PATTERN...        11        8
# 2865348     _WHITE_STRIPES_ADIDAS;PERSON;PATTERN_SH;PERSON         5        5
# 2865349             _ZAMALEK1213H;PERSON;PATTERN_SH;PERSON         4        4
# 2865350   _ZENIT1112A;PERSON;_ZENIT1112H PATTERN_SO;PERSON         5        5
# 2865351                      __NOTOC__;PERSON;JAPANESE;GPE        11        8
#
# [2865352 rows x 12 columns]

# %%
reldata=pandas.merge(reldata,
                                 entitydata,
                                 left_on=['B','Bt'],
                                 right_on=['A','At'],
                                 suffixes=['','_B'])
reldata
# Out:
#                                                    A            At  \
# 0                                           " ASIMOV        PERSON
# 1                                             ASIMOV        PERSON
# 2                                              " BEL        PERSON
# 3                                              " BEL        PERSON
# 4                                          FREMANTLE  ORGANIZATION
# 5                                          FT. LEWIS  ORGANIZATION
# 6                           JOINT BASE LEWIS-MCCHORD  ORGANIZATION
# 7                                 NAS WHIDBEY ISLAND  ORGANIZATION
# 8                                                NSW  ORGANIZATION
# 9                                                QLD           GPE
# 10                                                SA           GPE
# 11                                               VIC  ORGANIZATION
# 12                                            " ELIM        PERSON
# 13                                         " EVICTED        PERSON
# 14                                         " EVICTED        PERSON
# 15                                         9 EVICTED        PERSON
# 16                                           EVICTED        PERSON
# 17                                         " EVICTED        PERSON
# 18                                           " JAPAN        PERSON
# 19                                         " JOHNSON        PERSON
# 20                                       ALEX KRAMER        PERSON
# 21                                             CAMEO  ORGANIZATION
# 22                                             CAMEO        PERSON
# 23                                           CANDACE        PERSON
# 24                                   ROBBIE WILLIAMS        PERSON
# 25                                         " JOHNSON        PERSON
# 26                                         " JOHNSON        PERSON
# 27                                          BIG SHOW  ORGANIZATION
# 28                                      BROCK LESNAR        PERSON
# 29                                     CHRIS JERICHO        PERSON
# ...                                              ...           ...
# 1280529                  _BLACK_HOOPS_COLOR LEFTARM1       PRODUCT
# 1280530                               _BLACK_STRIPES        PERSON
# 1280531                                 _BLANKSIDES2        PERSON
# 1280532                                      _CRCH06        PERSON
# 1280533                                 _BLANKSIDES2        PERSON
# 1280534                         _BLUE_STRIPES_ADIDAS        PERSON
# 1280535                                      _CRCH06        PERSON
# 1280536                          _RED_STRIPES_ADIDAS        PERSON
# 1280537                              _SIDES_ON_WHITE        PERSON
# 1280538                        _CESENA1011A LEFTARM1       PRODUCT
# 1280539                     _CESENA1011H PATTERN_SO2      FACILITY
# 1280540                       _COLOR_3_STRIPES_BLACK        PERSON
# 1280541                       _COLOR_3_STRIPES_BLACK        PERSON
# 1280542  _SHOULDER_STRIPES_WHITE_STRIPES PATTERN_RA1       PRODUCT
# 1280543             _GOLD_STRIPES_ADIDAS PATTERN_SO2       PRODUCT
# 1280544                       _NUFC1011H PATTERN_SO2       PRODUCT
# 1280545                       _NUFC1011H PATTERN_SO2       PRODUCT
# 1280546                             _PUMA_2010_WHITE        PERSON
# 1280547                       _NUFC1011H PATTERN_SO2       PRODUCT
# 1280548                             _PUMA_2010_WHITE        PERSON
# 1280549                 _PUMA_2010_WHITE PATTERN_RA2       PRODUCT
# 1280550                                  _PORTO1415H        PERSON
# 1280551                                  _PORTO1415H        PERSON
# 1280552                      _PORTO1415H PATTERN_RA1       PRODUCT
# 1280553                             _PUMA_2010_WHITE        PERSON
# 1280554                                _REDSTAR1011A        PERSON
# 1280555              _RED_STRIPES_ADIDAS PATTERN_SO2       PRODUCT
# 1280556              _RED_STRIPES_ADIDAS PATTERN_SO2       PRODUCT
# 1280557                _SHOULDER_STRIPES_RED_STRIPES        PERSON
# 1280558                        _SCP1112H PATTERN_SO1       PRODUCT
#
#                                                    B            Bt  \
# 0                                            FICTION     TITLEWORK
# 1                                            FICTION     TITLEWORK
# 2                                                 VL  ORGANIZATION
# 3                                                 WA  ORGANIZATION
# 4                                                 WA  ORGANIZATION
# 5                                                 WA  ORGANIZATION
# 6                                                 WA  ORGANIZATION
# 7                                                 WA  ORGANIZATION
# 8                                                 WA  ORGANIZATION
# 9                                                 WA  ORGANIZATION
# 10                                                WA  ORGANIZATION
# 11                                                WA  ORGANIZATION
# 12                                          #FBF373"        PERSON
# 13                                            DAY 29          DATE
# 14                                             DAY 8          DATE
# 15                                             DAY 8          DATE
# 16                                             DAY 8          DATE
# 17                                             DAY 9          DATE
# 18                                            ORICON  ORGANIZATION
# 19                                             CANDY     TITLEWORK
# 20                                             CANDY     TITLEWORK
# 21                                             CANDY     TITLEWORK
# 22                                             CANDY     TITLEWORK
# 23                                             CANDY     TITLEWORK
# 24                                             CANDY     TITLEWORK
# 25                                     GUITAR JUNIOR     TITLEWORK
# 26                                          THE ROCK     TITLEWORK
# 27                                          THE ROCK     TITLEWORK
# 28                                          THE ROCK     TITLEWORK
# 29                                          THE ROCK     TITLEWORK
# ...                                              ...           ...
# 1280529              _SHOULDER_STRIPES_BLACK_STRIPES        PERSON
# 1280530                                 FF8C0D BODY1      FACILITY
# 1280531                                  A_PATTERN_S        PERSON
# 1280532                                  A_PATTERN_S        PERSON
# 1280533                                  H_PATTERN_S        PERSON
# 1280534                                  H_PATTERN_S        PERSON
# 1280535                                  H_PATTERN_S        PERSON
# 1280536                                  H_PATTERN_S        PERSON
# 1280537                                  H_PATTERN_S        PERSON
# 1280538                                 _DERBYC1011H        PERSON
# 1280539                                _MACCLES1112A        PERSON
# 1280540  _SHOULDER_STRIPES_WHITE_STRIPES PATTERN_RA1       PRODUCT
# 1280541                              _WHITE_STRIPES2        PERSON
# 1280542                              _WHITE_STRIPES2        PERSON
# 1280543                       _GOLD_LINES PATTERN_B2       PRODUCT
# 1280544                             _PUMA_2010_WHITE        PERSON
# 1280545                 _PUMA_2010_WHITE PATTERN_RA2       PRODUCT
# 1280546                 _PUMA_2010_WHITE PATTERN_RA2       PRODUCT
# 1280547                 _PUMA_2010_WHITE PATTERN_SH2       PRODUCT
# 1280548                 _PUMA_2010_WHITE PATTERN_SH2       PRODUCT
# 1280549                 _PUMA_2010_WHITE PATTERN_SH2       PRODUCT
# 1280550                      _PORTO1415H PATTERN_RA1       PRODUCT
# 1280551                      _PORTO1415H PATTERN_SH1       PRODUCT
# 1280552                      _PORTO1415H PATTERN_SH1       PRODUCT
# 1280553                 _PUMA_2010_WHITE PATTERN_RA1       PRODUCT
# 1280554                           _STRIPES_CUT_WHITE        PERSON
# 1280555                _SHOULDER_STRIPES_RED_STRIPES        PERSON
# 1280556    _SHOULDER_STRIPES_RED_STRIPES PATTERN_RA2       PRODUCT
# 1280557    _SHOULDER_STRIPES_RED_STRIPES PATTERN_RA2       PRODUCT
# 1280558                                    _SCP_HOME        PERSON
#
#             reltype  mAB  nDocs  \
# 0          authorOf    6      4
# 1          authorOf    6      6
# 2        employedBy   12     12
# 3        employedBy   18     18
# 4        colocation    5      5
# 5        colocation    4      4
# 6        colocation    7      7
# 7        colocation    6      6
# 8        colocation    9      9
# 9        colocation    5      5
# 10       colocation    4      4
# 11       colocation    7      7
# 12       colocation    4      4
# 13           bornOn    5      5
# 14           bornOn    8      8
# 15           bornOn    8      8
# 16           bornOn   11     11
# 17           bornOn    4      4
# 18       employedBy    5      5
# 19         authorOf    4      4
# 20       colocation   10     10
# 21       colocation    4      4
# 22         authorOf    8      7
# 23       colocation    4      4
# 24         authorOf    4      4
# 25         authorOf    5      4
# 26         authorOf    6      6
# 27       colocation    4      4
# 28       colocation    4      4
# 29       colocation   10      9
# ...             ...  ...    ...
# 1280529  colocation    4      4
# 1280530   locatedAt    5      5
# 1280531  colocation   25     25
# 1280532  colocation    6      6
# 1280533  colocation   65     65
# 1280534  colocation    4      4
# 1280535  colocation    9      9
# 1280536  colocation    4      4
# 1280537  colocation    4      4
# 1280538  colocation    6      6
# 1280539  colocation    5      5
# 1280540  colocation    4      4
# 1280541  colocation    4      4
# 1280542  colocation    5      5
# 1280543  colocation    6      6
# 1280544  colocation    4      4
# 1280545  colocation    4      4
# 1280546  colocation    9      9
# 1280547  colocation    4      4
# 1280548  colocation    9      9
# 1280549  colocation    9      9
# 1280550  colocation    4      4
# 1280551  colocation    4      4
# 1280552  colocation    4      4
# 1280553  colocation    4      4
# 1280554  colocation    4      4
# 1280555  colocation    5      5
# 1280556  colocation    5      5
# 1280557  colocation    5      5
# 1280558  colocation    4      4
#
#                                                  pattern_A  \
# 0                                          " ASIMOV;PERSON
# 1                                            ASIMOV;PERSON
# 2                                             " BEL;PERSON
# 3                                             " BEL;PERSON
# 4                                   FREMANTLE;ORGANIZATION
# 5                                   FT. LEWIS;ORGANIZATION
# 6                    JOINT BASE LEWIS-MCCHORD;ORGANIZATION
# 7                          NAS WHIDBEY ISLAND;ORGANIZATION
# 8                                         NSW;ORGANIZATION
# 9                                                  QLD;GPE
# 10                                                  SA;GPE
# 11                                        VIC;ORGANIZATION
# 12                                           " ELIM;PERSON
# 13                                        " EVICTED;PERSON
# 14                                        " EVICTED;PERSON
# 15                                        9 EVICTED;PERSON
# 16                                          EVICTED;PERSON
# 17                                        " EVICTED;PERSON
# 18                                          " JAPAN;PERSON
# 19                                        " JOHNSON;PERSON
# 20                                      ALEX KRAMER;PERSON
# 21                                      CAMEO;ORGANIZATION
# 22                                            CAMEO;PERSON
# 23                                          CANDACE;PERSON
# 24                                  ROBBIE WILLIAMS;PERSON
# 25                                        " JOHNSON;PERSON
# 26                                        " JOHNSON;PERSON
# 27                                   BIG SHOW;ORGANIZATION
# 28                                     BROCK LESNAR;PERSON
# 29                                    CHRIS JERICHO;PERSON
# ...                                                    ...
# 1280529                _BLACK_HOOPS_COLOR LEFTARM1;PRODUCT
# 1280530                              _BLACK_STRIPES;PERSON
# 1280531                                _BLANKSIDES2;PERSON
# 1280532                                     _CRCH06;PERSON
# 1280533                                _BLANKSIDES2;PERSON
# 1280534                        _BLUE_STRIPES_ADIDAS;PERSON
# 1280535                                     _CRCH06;PERSON
# 1280536                         _RED_STRIPES_ADIDAS;PERSON
# 1280537                             _SIDES_ON_WHITE;PERSON
# 1280538                      _CESENA1011A LEFTARM1;PRODUCT
# 1280539                  _CESENA1011H PATTERN_SO2;FACILITY
# 1280540                      _COLOR_3_STRIPES_BLACK;PERSON
# 1280541                      _COLOR_3_STRIPES_BLACK;PERSON
# 1280542  _SHOULDER_STRIPES_WHITE_STRIPES PATTERN_RA1;PR...
# 1280543           _GOLD_STRIPES_ADIDAS PATTERN_SO2;PRODUCT
# 1280544                     _NUFC1011H PATTERN_SO2;PRODUCT
# 1280545                     _NUFC1011H PATTERN_SO2;PRODUCT
# 1280546                            _PUMA_2010_WHITE;PERSON
# 1280547                     _NUFC1011H PATTERN_SO2;PRODUCT
# 1280548                            _PUMA_2010_WHITE;PERSON
# 1280549               _PUMA_2010_WHITE PATTERN_RA2;PRODUCT
# 1280550                                 _PORTO1415H;PERSON
# 1280551                                 _PORTO1415H;PERSON
# 1280552                    _PORTO1415H PATTERN_RA1;PRODUCT
# 1280553                            _PUMA_2010_WHITE;PERSON
# 1280554                               _REDSTAR1011A;PERSON
# 1280555            _RED_STRIPES_ADIDAS PATTERN_SO2;PRODUCT
# 1280556            _RED_STRIPES_ADIDAS PATTERN_SO2;PRODUCT
# 1280557               _SHOULDER_STRIPES_RED_STRIPES;PERSON
# 1280558                      _SCP1112H PATTERN_SO1;PRODUCT
#
#                                                  pattern_B  \
# 0                                        FICTION;TITLEWORK
# 1                                        FICTION;TITLEWORK
# 2                                          VL;ORGANIZATION
# 3                                          WA;ORGANIZATION
# 4                                          WA;ORGANIZATION
# 5                                          WA;ORGANIZATION
# 6                                          WA;ORGANIZATION
# 7                                          WA;ORGANIZATION
# 8                                          WA;ORGANIZATION
# 9                                          WA;ORGANIZATION
# 10                                         WA;ORGANIZATION
# 11                                         WA;ORGANIZATION
# 12                                         #FBF373";PERSON
# 13                                             DAY 29;DATE
# 14                                              DAY 8;DATE
# 15                                              DAY 8;DATE
# 16                                              DAY 8;DATE
# 17                                              DAY 9;DATE
# 18                                     ORICON;ORGANIZATION
# 19                                         CANDY;TITLEWORK
# 20                                         CANDY;TITLEWORK
# 21                                         CANDY;TITLEWORK
# 22                                         CANDY;TITLEWORK
# 23                                         CANDY;TITLEWORK
# 24                                         CANDY;TITLEWORK
# 25                                 GUITAR JUNIOR;TITLEWORK
# 26                                      THE ROCK;TITLEWORK
# 27                                      THE ROCK;TITLEWORK
# 28                                      THE ROCK;TITLEWORK
# 29                                      THE ROCK;TITLEWORK
# ...                                                    ...
# 1280529             _SHOULDER_STRIPES_BLACK_STRIPES;PERSON
# 1280530                              FF8C0D BODY1;FACILITY
# 1280531                                 A_PATTERN_S;PERSON
# 1280532                                 A_PATTERN_S;PERSON
# 1280533                                 H_PATTERN_S;PERSON
# 1280534                                 H_PATTERN_S;PERSON
# 1280535                                 H_PATTERN_S;PERSON
# 1280536                                 H_PATTERN_S;PERSON
# 1280537                                 H_PATTERN_S;PERSON
# 1280538                                _DERBYC1011H;PERSON
# 1280539                               _MACCLES1112A;PERSON
# 1280540  _SHOULDER_STRIPES_WHITE_STRIPES PATTERN_RA1;PR...
# 1280541                             _WHITE_STRIPES2;PERSON
# 1280542                             _WHITE_STRIPES2;PERSON
# 1280543                     _GOLD_LINES PATTERN_B2;PRODUCT
# 1280544                            _PUMA_2010_WHITE;PERSON
# 1280545               _PUMA_2010_WHITE PATTERN_RA2;PRODUCT
# 1280546               _PUMA_2010_WHITE PATTERN_RA2;PRODUCT
# 1280547               _PUMA_2010_WHITE PATTERN_SH2;PRODUCT
# 1280548               _PUMA_2010_WHITE PATTERN_SH2;PRODUCT
# 1280549               _PUMA_2010_WHITE PATTERN_SH2;PRODUCT
# 1280550                    _PORTO1415H PATTERN_RA1;PRODUCT
# 1280551                    _PORTO1415H PATTERN_SH1;PRODUCT
# 1280552                    _PORTO1415H PATTERN_SH1;PRODUCT
# 1280553               _PUMA_2010_WHITE PATTERN_RA1;PRODUCT
# 1280554                          _STRIPES_CUT_WHITE;PERSON
# 1280555               _SHOULDER_STRIPES_RED_STRIPES;PERSON
# 1280556  _SHOULDER_STRIPES_RED_STRIPES PATTERN_RA2;PRODUCT
# 1280557  _SHOULDER_STRIPES_RED_STRIPES PATTERN_RA2;PRODUCT
# 1280558                                   _SCP_HOME;PERSON
#
#                                                    pattern  relcount  nDocs_A  \
# 0                        " ASIMOV;PERSON;FICTION;TITLEWORK        18        6
# 1                          ASIMOV;PERSON;FICTION;TITLEWORK      1362      352
# 2                             " BEL;PERSON;VL;ORGANIZATION        35       30
# 3                             " BEL;PERSON;WA;ORGANIZATION        35       30
# 4                   FREMANTLE;ORGANIZATION;WA;ORGANIZATION       717      314
# 5                   FT. LEWIS;ORGANIZATION;WA;ORGANIZATION        15        7
# 6        JOINT BASE LEWIS-MCCHORD;ORGANIZATION;WA;ORGAN...       231       96
# 7          NAS WHIDBEY ISLAND;ORGANIZATION;WA;ORGANIZATION       169       60
# 8                         NSW;ORGANIZATION;WA;ORGANIZATION      2003      935
# 9                                  QLD;GPE;WA;ORGANIZATION       638      380
# 10                                  SA;GPE;WA;ORGANIZATION       943      601
# 11                        VIC;ORGANIZATION;WA;ORGANIZATION       214      158
# 12                           " ELIM;PERSON;#FBF373";PERSON        15        7
# 13                            " EVICTED;PERSON;DAY 29;DATE       392       43
# 14                             " EVICTED;PERSON;DAY 8;DATE       392       43
# 15                             9 EVICTED;PERSON;DAY 8;DATE       119       27
# 16                               EVICTED;PERSON;DAY 8;DATE       551       62
# 17                             " EVICTED;PERSON;DAY 9;DATE       392       43
# 18                      " JAPAN;PERSON;ORICON;ORGANIZATION         8        8
# 19                        " JOHNSON;PERSON;CANDY;TITLEWORK       169       76
# 20                      ALEX KRAMER;PERSON;CANDY;TITLEWORK       141       54
# 21                      CAMEO;ORGANIZATION;CANDY;TITLEWORK       573      259
# 22                            CAMEO;PERSON;CANDY;TITLEWORK       300      139
# 23                          CANDACE;PERSON;CANDY;TITLEWORK      1056      238
# 24                  ROBBIE WILLIAMS;PERSON;CANDY;TITLEWORK      2022      938
# 25                " JOHNSON;PERSON;GUITAR JUNIOR;TITLEWORK       169       76
# 26                     " JOHNSON;PERSON;THE ROCK;TITLEWORK       169       76
# 27                BIG SHOW;ORGANIZATION;THE ROCK;TITLEWORK       890      148
# 28                  BROCK LESNAR;PERSON;THE ROCK;TITLEWORK      1630      233
# 29                 CHRIS JERICHO;PERSON;THE ROCK;TITLEWORK      3956      556
# ...                                                    ...       ...      ...
# 1280529  _BLACK_HOOPS_COLOR LEFTARM1;PRODUCT;_SHOULDER_...        12        4
# 1280530        _BLACK_STRIPES;PERSON;FF8C0D BODY1;FACILITY        33       25
# 1280531             _BLANKSIDES2;PERSON;A_PATTERN_S;PERSON       112      110
# 1280532                  _CRCH06;PERSON;A_PATTERN_S;PERSON        16       15
# 1280533             _BLANKSIDES2;PERSON;H_PATTERN_S;PERSON       112      110
# 1280534     _BLUE_STRIPES_ADIDAS;PERSON;H_PATTERN_S;PERSON        18       16
# 1280535                  _CRCH06;PERSON;H_PATTERN_S;PERSON        16       15
# 1280536      _RED_STRIPES_ADIDAS;PERSON;H_PATTERN_S;PERSON        22       21
# 1280537          _SIDES_ON_WHITE;PERSON;H_PATTERN_S;PERSON        14       14
# 1280538  _CESENA1011A LEFTARM1;PRODUCT;_DERBYC1011H;PERSON        18        6
# 1280539  _CESENA1011H PATTERN_SO2;FACILITY;_MACCLES1112...        10        5
# 1280540  _COLOR_3_STRIPES_BLACK;PERSON;_SHOULDER_STRIPE...        34       23
# 1280541  _COLOR_3_STRIPES_BLACK;PERSON;_WHITE_STRIPES2;...        34       23
# 1280542  _SHOULDER_STRIPES_WHITE_STRIPES PATTERN_RA1;PR...        20       11
# 1280543  _GOLD_STRIPES_ADIDAS PATTERN_SO2;PRODUCT;_GOLD...        12        6
# 1280544  _NUFC1011H PATTERN_SO2;PRODUCT;_PUMA_2010_WHIT...        15        4
# 1280545  _NUFC1011H PATTERN_SO2;PRODUCT;_PUMA_2010_WHIT...        15        4
# 1280546  _PUMA_2010_WHITE;PERSON;_PUMA_2010_WHITE PATTE...        33       14
# 1280547  _NUFC1011H PATTERN_SO2;PRODUCT;_PUMA_2010_WHIT...        15        4
# 1280548  _PUMA_2010_WHITE;PERSON;_PUMA_2010_WHITE PATTE...        33       14
# 1280549  _PUMA_2010_WHITE PATTERN_RA2;PRODUCT;_PUMA_201...        13        9
# 1280550  _PORTO1415H;PERSON;_PORTO1415H PATTERN_RA1;PRO...        12        4
# 1280551  _PORTO1415H;PERSON;_PORTO1415H PATTERN_SH1;PRO...        12        4
# 1280552  _PORTO1415H PATTERN_RA1;PRODUCT;_PORTO1415H PA...         8        4
# 1280553  _PUMA_2010_WHITE;PERSON;_PUMA_2010_WHITE PATTE...        33       14
# 1280554     _REDSTAR1011A;PERSON;_STRIPES_CUT_WHITE;PERSON         4        4
# 1280555  _RED_STRIPES_ADIDAS PATTERN_SO2;PRODUCT;_SHOUL...        15        5
# 1280556  _RED_STRIPES_ADIDAS PATTERN_SO2;PRODUCT;_SHOUL...        15        5
# 1280557  _SHOULDER_STRIPES_RED_STRIPES;PERSON;_SHOULDER...        19       10
# 1280558     _SCP1112H PATTERN_SO1;PRODUCT;_SCP_HOME;PERSON         8        4
#
#                                                  A_B          At_B  \
# 0                                            FICTION     TITLEWORK
# 1                                            FICTION     TITLEWORK
# 2                                                 VL  ORGANIZATION
# 3                                                 WA  ORGANIZATION
# 4                                                 WA  ORGANIZATION
# 5                                                 WA  ORGANIZATION
# 6                                                 WA  ORGANIZATION
# 7                                                 WA  ORGANIZATION
# 8                                                 WA  ORGANIZATION
# 9                                                 WA  ORGANIZATION
# 10                                                WA  ORGANIZATION
# 11                                                WA  ORGANIZATION
# 12                                          #FBF373"        PERSON
# 13                                            DAY 29          DATE
# 14                                             DAY 8          DATE
# 15                                             DAY 8          DATE
# 16                                             DAY 8          DATE
# 17                                             DAY 9          DATE
# 18                                            ORICON  ORGANIZATION
# 19                                             CANDY     TITLEWORK
# 20                                             CANDY     TITLEWORK
# 21                                             CANDY     TITLEWORK
# 22                                             CANDY     TITLEWORK
# 23                                             CANDY     TITLEWORK
# 24                                             CANDY     TITLEWORK
# 25                                     GUITAR JUNIOR     TITLEWORK
# 26                                          THE ROCK     TITLEWORK
# 27                                          THE ROCK     TITLEWORK
# 28                                          THE ROCK     TITLEWORK
# 29                                          THE ROCK     TITLEWORK
# ...                                              ...           ...
# 1280529              _SHOULDER_STRIPES_BLACK_STRIPES        PERSON
# 1280530                                 FF8C0D BODY1      FACILITY
# 1280531                                  A_PATTERN_S        PERSON
# 1280532                                  A_PATTERN_S        PERSON
# 1280533                                  H_PATTERN_S        PERSON
# 1280534                                  H_PATTERN_S        PERSON
# 1280535                                  H_PATTERN_S        PERSON
# 1280536                                  H_PATTERN_S        PERSON
# 1280537                                  H_PATTERN_S        PERSON
# 1280538                                 _DERBYC1011H        PERSON
# 1280539                                _MACCLES1112A        PERSON
# 1280540  _SHOULDER_STRIPES_WHITE_STRIPES PATTERN_RA1       PRODUCT
# 1280541                              _WHITE_STRIPES2        PERSON
# 1280542                              _WHITE_STRIPES2        PERSON
# 1280543                       _GOLD_LINES PATTERN_B2       PRODUCT
# 1280544                             _PUMA_2010_WHITE        PERSON
# 1280545                 _PUMA_2010_WHITE PATTERN_RA2       PRODUCT
# 1280546                 _PUMA_2010_WHITE PATTERN_RA2       PRODUCT
# 1280547                 _PUMA_2010_WHITE PATTERN_SH2       PRODUCT
# 1280548                 _PUMA_2010_WHITE PATTERN_SH2       PRODUCT
# 1280549                 _PUMA_2010_WHITE PATTERN_SH2       PRODUCT
# 1280550                      _PORTO1415H PATTERN_RA1       PRODUCT
# 1280551                      _PORTO1415H PATTERN_SH1       PRODUCT
# 1280552                      _PORTO1415H PATTERN_SH1       PRODUCT
# 1280553                 _PUMA_2010_WHITE PATTERN_RA1       PRODUCT
# 1280554                           _STRIPES_CUT_WHITE        PERSON
# 1280555                _SHOULDER_STRIPES_RED_STRIPES        PERSON
# 1280556    _SHOULDER_STRIPES_RED_STRIPES PATTERN_RA2       PRODUCT
# 1280557    _SHOULDER_STRIPES_RED_STRIPES PATTERN_RA2       PRODUCT
# 1280558                                    _SCP_HOME        PERSON
#
#          relcount_B  nDocs_B
# 0               238       83
# 1               238       83
# 2                 8        6
# 3                86       66
# 4                86       66
# 5                86       66
# 6                86       66
# 7                86       66
# 8                86       66
# 9                86       66
# 10               86       66
# 11               86       66
# 12               15        8
# 13               18       15
# 14               39       35
# 15               39       35
# 16               39       35
# 17               21       16
# 18               91       63
# 19              418      178
# 20              418      178
# 21              418      178
# 22              418      178
# 23              418      178
# 24              418      178
# 25               19        8
# 26              414      254
# 27              414      254
# 28              414      254
# 29              414      254
# ...             ...      ...
# 1280529          15        9
# 1280530         211       80
# 1280531          16       13
# 1280532          16       13
# 1280533           4        4
# 1280534           4        4
# 1280535           4        4
# 1280536           4        4
# 1280537           4        4
# 1280538          12        6
# 1280539           9        9
# 1280540          20       11
# 1280541          11        8
# 1280542          11        8
# 1280543           6        6
# 1280544          33       14
# 1280545          13        9
# 1280546          13        9
# 1280547           4        4
# 1280548           4        4
# 1280549           4        4
# 1280550           8        4
# 1280551           4        4
# 1280552           4        4
# 1280553           6        4
# 1280554          10       10
# 1280555          19       10
# 1280556           5        5
# 1280557           5        5
# 1280558           4        4
#
# [1280559 rows x 16 columns]

# %%
N_SAMPLES = 2000

# %%
#sampling
rows = numpy.random.choice(reldata.index.values,N_SAMPLES)
samples_pos = reldata.ix[rows,['A','At','B','Bt']]
samples_pos
# Out:
#                                          A            At  \
# 777994                       BLAISE PASCAL        PERSON
# 1232571            NAVY COMMENDATION MEDAL  ORGANIZATION
# 387660                     BOLSHEVIK PARTY  ORGANIZATION
# 602435                          JUAN PERON        PERSON
# 356339                    NASJONAL SAMLING        PERSON
# 1075254                    ROBERT BENFIELD        PERSON
# 754091       BIG CYPRESS NATIONAL PRESERVE  ORGANIZATION
# 491337                         CASEY JONES        PERSON
# 632921                       AUGUSTE DUPIN        PERSON
# 512315                   LAURA HILLENBRAND        PERSON
# 786974                           HAL MCCOY        PERSON
# 600494                     ARTHUR STREETON        PERSON
# 206844                            PHILLIES       PRODUCT
# 1068021                        FBI UNIFORM  ORGANIZATION
# 123171                             RED SOX  ORGANIZATION
# 984591                        DANIEL BOONE        PERSON
# 439727                     THE ROUGH GUIDE  ORGANIZATION
# 139344            AKBAR HASHEMI RAFSANJANI        PERSON
# 1062473  EVANGELICAL FRIENDS INTERNATIONAL  ORGANIZATION
# 693879                          KANYE WEST  ORGANIZATION
# 220112                           ADDICTION        PERSON
# 128055                      INGUS BAUMANIS        PERSON
# 1157705                           JACOBSON  ORGANIZATION
# 109665                              COOK 5        PERSON
# 1128410                              HAVEN           GPE
# 117243                                SABU        PERSON
# 1004630                         DEMON SEED        PERSON
# 863259           CAMPEONATO PAULISTA SERIE        PERSON
# 124897                            FREE MAN        PERSON
# 1258509           ROYAL ANTEDILUVIAN ORDER  ORGANIZATION
# ...                                    ...           ...
# 5743                  JAMES DEAN BRADFIELD        PERSON
# 81137                    HUNDRED YEARS WAR  ORGANIZATION
# 1175829                       JORDAN PEELE        PERSON
# 1000931                   DECEMBER 3, 1981          DATE
# 315024                       TIM WAKEFIELD        PERSON
# 605573                    HELENA BLAVATSKY        PERSON
# 896524                    OLDHAM ROUGHYEDS        PERSON
# 1201627                       LEVSKI SOFIA        PERSON
# 102341                              DUPREE        PERSON
# 968429                   CRAIGSLIST KILLER  ORGANIZATION
# 1035841                            LEDYARD           GPE
# 725925                         BEN JOHNSON        PERSON
# 260900             NORTH KOREAN GOVERNMENT           GPE
# 68694                 FIGURE SKATING FINAL  ORGANIZATION
# 115568                   NASCAR CUP SERIES  EVENT_SPORTS
# 646248                      OGDEN TOWNSHIP        PERSON
# 1075394                    FLINDERS PETRIE        PERSON
# 714290                      DISNEY DIGITAL  ORGANIZATION
# 198514                          THE FRIDGE  ORGANIZATION
# 747848                         ED HARCOURT        PERSON
# 794287                         BOFROST CUP      FACILITY
# 1104098              JOSE FROILAN GONZALEZ        PERSON
# 4910                          GRACE POTTER        PERSON
# 679989                    SOUTHERN PACIFIC      LOCATION
# 968526                            CRANBURY           GPE
# 761868                     DONNIE WAHLBERG        PERSON
# 82194                     AMERIGO VESPUCCI        PERSON
# 822122                      BRIAN HARGROVE        PERSON
# 818297                       BRENDAN BYRNE        PERSON
# 204673                         LEA MICHELE        PERSON
#
#                                            B            Bt
# 777994                      CLERMONT-FERRAND           GPE
# 1232571                             COMBAT V  ORGANIZATION
# 387660                             PETROGRAD           GPE
# 602435                REVOLUCION LIBERTADORA  ORGANIZATION
# 356339                       VIDKUN QUISLING        PERSON
# 1075254                   WILLIAM ECCLESTONE        PERSON
# 754091              EVERGLADES NATIONAL PARK  ORGANIZATION
# 491337                             DONATELLO        PERSON
# 632921                           THE MURDERS     TITLEWORK
# 512315                       LOUIS ZAMPERINI        PERSON
# 786974                           RICK HUMMEL        PERSON
# 600494                            FRED LEIST        PERSON
# 206844                                  REDS  ORGANIZATION
# 1068021            U.S. CONFERENCE OF MAYORS  ORGANIZATION
# 123171                      ST. LOUIS BROWNS           GPE
# 984591                            LARRY PAGE        PERSON
# 439727                           WORLD MUSIC  ORGANIZATION
# 139344                    IRANIAN REVOLUTION           GPE
# 1062473           FRIENDS GENERAL CONFERENCE  ORGANIZATION
# 693879                             LL COOL J  ORGANIZATION
# 220112                       STEPHEN PERKINS        PERSON
# 128055                                   LAT  ORGANIZATION
# 1157705                               SAT270  ORGANIZATION
# 109665                               ASSIST1        PERSON
# 1128410                       STRAITS COURSE  ORGANIZATION
# 117243                                MATCH8        PERSON
# 1004630                       DONALD CAMMELL        PERSON
# 863259                           SANTO ANDRE        PERSON
# 124897                                 COLOR           GPE
# 1258509                            BUFFALOES  ORGANIZATION
# ...                                      ...           ...
# 5743                                   ALBUM     TITLEWORK
# 81137                      WARS OF THE ROSES  ORGANIZATION
# 1175829                   KEEGAN-MICHAEL KEY        PERSON
# 1000931  NANKING PURPLE MOUNTAIN OBSERVATORY     TITLEWORK
# 315024                           TOM GLAVINE        PERSON
# 605573                             THEOSOPHY           GPE
# 896524                      ROCHDALE HORNETS           GPE
# 1201627                 VASIL LEVSKI STADIUM        PERSON
# 102341                             REBOUNDS2        PERSON
# 968429                       JULISSA BRISMAN        PERSON
# 1035841                            MONTVILLE           GPE
# 725925                       CHARLIE FRANCIS        PERSON
# 260900       UNITED NATIONS SECURITY COUNCIL  ORGANIZATION
# 68694                       GRAND PRIX FINAL  EVENT_SPORTS
# 115568                         RICHARD PETTY        PERSON
# 646248                      CHAMPAIGN COUNTY           GPE
# 1075394                        PETRIE MUSEUM        PERSON
# 714290                  WALT DISNEY PICTURES  ORGANIZATION
# 198514                               BRIXTON           GPE
# 747848                         JIMMY HOGARTH        PERSON
# 794287                                   ICE      FACILITY
# 1104098                     UMBERTO MAGLIOLI        PERSON
# 4910                                   ALBUM     TITLEWORK
# 679989                         UNION PACIFIC  ORGANIZATION
# 968526                             JAMESBURG           GPE
# 761868                        JOHN LEGUIZAMO        PERSON
# 82194                        NEW YORK HARBOR           GPE
# 822122                            JACK KENNY        PERSON
# 818297                       RAYMOND BATEMAN        PERSON
# 204673                                  GLEE  ORGANIZATION
#
# [2000 rows x 4 columns]

# %% [markdown]
# ##Negative Sampling

# %% [markdown]
# Idea: pick random rows from reldata_filtered, then use them as one of the following: AX, XA.
#
# Find an XB or BX in reldata_filtered for this choice.
#
# Report back AB.

# %%
N_SAMPLES = 2000

# %%
rows = numpy.random.choice(reldata.index.values,N_SAMPLES)
negative_AX = reldata.ix[rows,:].reset_index()

# %%
count = 0
#helper function for sampling an AB using a given row as a starting point
def sample_AB(row):
    #print row
    #pdb.set_trace()
    global count
    count = count+1
    matches = ['AA','AB','BA','BB'] #indicates whether we're matching the A with the A, the A with the B, etc.
    relevant_Cs = OrderedDict()
    #find the rows in reldata_significant that match the row with any one of the 4 patterns.
    for match in matches:
        idxs = (reldata['pattern_'+match[0]]== row['pattern_'+match[1]])&~(reldata['pattern']==row['pattern'])
        relevant_Cs[match] = reldata[idxs]
        relevant_Cs[match]['match'] = match
    relevant_C = pandas.concat(relevant_Cs.values(),ignore_index=True)
    if len(relevant_C) == 0:
        #print 'null'
        return 'null'
    else:
        location = numpy.random.choice(relevant_C.index.values)
        match = relevant_C.ix[location,'match']
        opposite_match = matches[-1-matches.index(match)]
        pattern_A = row['pattern_'+opposite_match[1]]
        pattern_B = relevant_C.ix[location,'pattern_'+opposite_match[0]]
    print count, " ", pattern_A+';'+pattern_B
    return pattern_A+';'+pattern_B

def test(row):
    global count
    count = count +1
    print row
    pdb.set_trace()
    return '1'

# %%
negative_AXB = pandas.DataFrame()
negative_AXB['pattern_AB'] = negative_AX.apply(func=sample_AB, axis=1)
negative_AXB = negative_AXB[~(negative_AXB['pattern_AB']=='null')]
# Out:
# 1   HUSH PUPPY;PERSON;SHARI LEWIS;PERSON
# 2   JOAN MURPHY;PERSON;KATE KELLY;PERSON
# 3   STANLEY KUBRICK;PERSON;AVRIL LAVIGNE;PERSON
# 4   JOEY LAWRENCE;PERSON;TOON DISNEY;PERSON
# 5   MIHAJLO KRESIMIR II;PERSON;SWEYN ESTRIDSON;PERSON
# /usr/local/lib/python2.7/dist-packages/ipython-3.1.0-py2.7.egg/IPython/kernel/__main__.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
def split_AB(row,i=0):
    pieces = str(row['pattern_AB']).split(';')
    if (len(pieces)==4):
        return pieces[i]
    else:
        return 'null'

# %%
negative_AXB['A'] = negative_AXB.apply(lambda x: split_AB(x,0),axis=1)
negative_AXB['At'] = negative_AXB.apply(lambda x: split_AB(x,1),axis=1)
negative_AXB['B'] = negative_AXB.apply(lambda x: split_AB(x,2),axis=1)
negative_AXB['Bt'] = negative_AXB.apply(lambda x: split_AB(x,3),axis=1)
negative_AXB[['A','At','B','Bt']]
# Out:
#                                      A            At  \
# 0                   EDMONTON OIL KINGS        PERSON
# 1     FIA WORLD ENDURANCE CHAMPIONSHIP  ORGANIZATION
# 2            ROYAL SOCIETY OF PAINTERS  ORGANIZATION
# 3                          CA WOODWARD           GPE
# 4                       GRAJEWO COUNTY           GPE
# 5                        PICKUP TRUCKS       VEHICLE
# 6                        GEORGE BENSON        PERSON
# 7                      PRINCESS LOUISE        PERSON
# 9                  ALFRED L. BULWINKLE        PERSON
# 10                  PARRAMATTA STADIUM        PERSON
# 11                                JPEG  ORGANIZATION
# 12                     ISABELLA LINTON        PERSON
# 13                        LEW ROCKWELL        PERSON
# 14              THE FABULOUS FREEBIRDS  ORGANIZATION
# 15                             G. LOVE        PERSON
# 16                    KERRY WASHINGTON        PERSON
# 17                     ZINEDINE ZIDANE        PERSON
# 18                       THE NEW ORDER  ORGANIZATION
# 19       FRANCESCO SAVERIO CASTIGLIONI        PERSON
# 20                       VIGYAN PRASAR        PERSON
# 21                          YUJI HORII        PERSON
# 22                      GAYLORD DUBOIS        PERSON
# 23                            GAO LING        PERSON
# 24                        DINO FEKARIS        PERSON
# 25                    JOHN D. MCDONALD        PERSON
# 26                                ATHY        PERSON
# 27                             ROBBERS           GPE
# 28                    APERAHAMA TAONUI        PERSON
# 29                             MIGRANT        PEOPLE
# 30                       VEU FELDKIRCH        PERSON
# ...                                ...           ...
# 1970                        WORDSWORTH           GPE
# 1971                         PURE LAND        PERSON
# 1972                     JOHN FRAMPTON        PERSON
# 1973               BAJA CALIFORNIA SUR           GPE
# 1974                     WANG YUANYING        PERSON
# 1975                          GUDIVADA           GPE
# 1976                     GEORGE NEWTON        PERSON
# 1977                     GEORGE LAKING        PERSON
# 1978                         ANTIPATER        PERSON
# 1979                       JANET BLAIR        PERSON
# 1980       DIRECT LABOUR ORGANISATIONS  ORGANIZATION
# 1981                      DON WHILLANS        PERSON
# 1982                         TEX AVERY        PERSON
# 1983            GOVINDUDU ANDARIVADELE        PERSON
# 1984                 FRENCH GRAND PRIX  EVENT_SPORTS
# 1985                   SHOGUN ASSASSIN        PERSON
# 1986                       TENTERFIELD           GPE
# 1987                      FRA ANGELICO        PERSON
# 1988                      DEWEY MARTIN        PERSON
# 1989                  GABRIELA MISTRAL        PERSON
# 1990                       ROBERT SUSZ        PERSON
# 1991                            BUZZIN        PERSON
# 1992                       EDWARDS AFB        PERSON
# 1993                    IRKUTSK OBLAST  ORGANIZATION
# 1994                    WALTER STEWARD        PERSON
# 1995                      END OF GREYS     TITLEWORK
# 1996                       JANE BIRKIN        PERSON
# 1997        AUGUSTA NATIONAL GOLF CLUB  ORGANIZATION
# 1998             FALCARIA LACERTINARIA        PERSON
# 1999              BEST QUALITY OF LIFE     TITLEWORK
#
#                                         B            Bt
# 0                           WINNIPEG JETS  ORGANIZATION
# 1                                     FIA  ORGANIZATION
# 2                                PAINTERS           GPE
# 3                               PLATFORMS  ORGANIZATION
# 4                          GMINA AUGUSTOW        PERSON
# 5                                 PEUGEOT       VEHICLE
# 6             GOT TO GET YOU INTO MY LIFE     TITLEWORK
# 7                      ERNST FREDERICK II        PERSON
# 9                         GEORGE H. MAHON        PERSON
# 10                       NORTH QUEENSLAND      FACILITY
# 11                                    PNG  ORGANIZATION
# 12                             AGNES GREY        PERSON
# 13                        FRIEDRICH HAYEK        PERSON
# 14                          MICHAEL HAYES        PERSON
# 15                           JACK JOHNSON        PERSON
# 16                         JOSEPH SURFACE        PERSON
# 17    UEFA EUROPEAN FOOTBALL CHAMPIONSHIP  ORGANIZATION
# 18                          SCOTT ASHETON        PERSON
# 19                            GREGORY XVI        PERSON
# 20            DEPARTMENT OF BIOTECHNOLOGY  ORGANIZATION
# 21                          DRAGON BALL Z  ORGANIZATION
# 22                              ALEX TOTH        PERSON
# 23                               YANG WEI        PERSON
# 24                       CHRISTINE YARIAN        PERSON
# 25                             ROD TAYLOR        PERSON
# 26                                   ATHY           GPE
# 27                                 CUTTIN        PERSON
# 28                              TE TAONUI        PERSON
# 29                                   COVE           GPE
# 30                 AUSTRIAN HOCKEY LEAGUE  ORGANIZATION
# ...                                   ...           ...
# 1970                               NEBULA           GPE
# 1971                KHEDRUP GELEK PELZANG  ORGANIZATION
# 1972                   HISTORIA MEDICINAL        PERSON
# 1973                         NUEVA ESPANA        PERSON
# 1974                              CHENGDU        PERSON
# 1975                          RAJAHMUNDRY           GPE
# 1976                        JAMES BELUSHI        PERSON
# 1977                       CARL BERENDSEN        PERSON
# 1978                DEMETRIUS POLIORCETES        PERSON
# 1979                                 FILM     TITLEWORK
# 1980             GENERAL MEDICAL SERVICES  ORGANIZATION
# 1981                           IAN CLOUGH        PERSON
# 1982                      SPEEDY GONZALES  ORGANIZATION
# 1983                      RAM GOPAL VARMA  ORGANIZATION
# 1984                   JUAN PABLO MONTOYA        PERSON
# 1985                       BRIAN WILLIAMS        PERSON
# 1986                              HELIDON           GPE
# 1987                             NATIVITY           GPE
# 1988                       MURRAY MACLEOD        PERSON
# 1989                    INNOCENT ERENDIRA        PERSON
# 1990                           PAUL KELLY        PERSON
# 1991                               KISSIN        PERSON
# 1992                             SIKORSKY  ORGANIZATION
# 1993                              MAGADAN           GPE
# 1994                               COMBER           GPE
# 1995                    LILANDRA NERAMANI        PERSON
# 1996                             ACE HOOD        PERSON
# 1997                       MAURICE CHEEKS        PERSON
# 1998                   EPIONE VESPERTARIA        PERSON
# 1999                        BEST COLLEGES         AWARD
#
# [1942 rows x 4 columns]

# %%
set_negative_AXB = set([tuple(x) for x in negative_AXB[['A','At','B','Bt']].values.tolist()])
set_rel = set([tuple(x) for x in reldata[['A','At','B','Bt']].values.tolist()])
set_rel_reverse = set([tuple(x) for x in reldata[['B','Bt','A','At']].values.tolist()])
set_diff = set_negative_AXB - set_rel - set_rel_reverse

# %%
samples_neg = pandas.DataFrame(list(set_diff),columns=['A','At','B','Bt'])
samples_neg
# Out:
#                                                       A            At  \
# 0                                      RAUNDALEN VALLEY           GPE
# 1                                        DANIEL DAE KIM        PERSON
# 2                                              GOERLITZ           GPE
# 3                                          JACK WORRALL        PERSON
# 4                               25PX PENNSYLVANIA ROUTE        PERSON
# 5                                      MAHESH MANJREKAR        PERSON
# 6                                              CHARLENE        PERSON
# 7                                       GRAND ICE CREAM      FACILITY
# 8     ASSOCIATION OF AMERICAN COLLEGES AND UNIVERSITIES  ORGANIZATION
# 9                                    KING GEORGE STAKES        PERSON
# 10                                        RICHARD DAVIS        PERSON
# 11                                        SOUTHERN ROCK           GPE
# 12                              STATE COMMUNITY COLLEGE  ORGANIZATION
# 13                                    HELIX HIGH SCHOOL  ORGANIZATION
# 14                                           KIM GORDON        PERSON
# 15                                  TEJANO MUSIC AWARDS  ORGANIZATION
# 16                                                  VDC        PERSON
# 17                                             BESSEMER           GPE
# 18            INSTITUTE OF SOCIAL AND ECONOMIC RESEARCH  ORGANIZATION
# 19                                        VAN BUREN ST.        PERSON
# 20                                        C.S. FORESTER        PERSON
# 21                                        PEE WEE ELLIS        PERSON
# 22                          DISTINGUISHED SERVICE AWARD  ORGANIZATION
# 23                   FRANCISCO ANTONIO PEREIRA COUTINHO        PERSON
# 24                  ANNA SUSANNA VON MEGGAU ZU KREUTZEN        PERSON
# 25                                              VANDALS  ORGANIZATION
# 26                                            BIG BASIN           GPE
# 27                                             CHARGING   EVENT_LEGAL
# 28                                        TYPHOID FEVER       DISEASE
# 29                                       ANTONY HEGARTY        PERSON
# ...                                                 ...           ...
# 1617                                   DISUSED STATIONS      FACILITY
# 1618                                              ALPHA       PRODUCT
# 1619                                             MARK 3        PERSON
# 1620                                       LISA STEVENS        PERSON
# 1621                                MOORESTOWN TOWNSHIP           GPE
# 1622                                           BRINDISI           GPE
# 1623                                  COUNT OF SOISSONS           GPE
# 1624                          COMMUNICATION ENGINEERING  ORGANIZATION
# 1625                                    JOSH HUTCHERSON        PERSON
# 1626                                          TAJH BOYD        PERSON
# 1627                                     ANGLO-AMERICAN  ORGANIZATION
# 1628                                         FANNIE MAE           GPE
# 1629                           TOPOGRAPHICAL DICTIONARY        PERSON
# 1630                                      U.S. ROUTE 50      FACILITY
# 1631                                               ERDA           GPE
# 1632                                     ANDO HIROSHIGE        PERSON
# 1633                                      CORY MONTEITH        PERSON
# 1634                                          SCYTHIANS           GPE
# 1635                                           BUKOVINA        PERSON
# 1636                                               AXIS      LOCATION
# 1637                                            HALL J.        PERSON
# 1638                                 PLOETZENSEE PRISON  ORGANIZATION
# 1639                            MARINE MILITARY ACADEMY  ORGANIZATION
# 1640                                  DWAYNE DE ROSARIO        PERSON
# 1641                                           CHINO XL           GPE
# 1642                          NEW TESTAMENT MANUSCRIPTS  ORGANIZATION
# 1643                                   KUJULA KADPHISES        PERSON
# 1644                                       COLE ALDRICH        PERSON
# 1645                                          ARROWHEAD  ORGANIZATION
# 1646                                          HURRICANE        PERSON
#
#                                                       B            Bt
# 0                                  OSTEROY MUNICIPALITY           GPE
# 1                                        DANNY WILLIAMS        PERSON
# 2                                            RABBI MEIR        PERSON
# 3                                               ROUND 7        PERSON
# 4                              25PX WEST VIRGINIA ROUTE        PERSON
# 5                                           JUHI CHAWLA        PERSON
# 6                                         HOSNI MUBARAK        PERSON
# 7                                             EDWARD L.        PERSON
# 8     AMERICAN ASSOCIATION OF STATE COLLEGES AND UNI...  ORGANIZATION
# 9                                     CORONATION STAKES        PERSON
# 10                                          TOM HARRELL        PERSON
# 11                                                  CCM           GPE
# 12                                              MCCOIST        PERSON
# 13                                          LEMON GROVE           GPE
# 14                                      JOAQUIN PHOENIX        PERSON
# 15                                                 SONG     TITLEWORK
# 16                                  LIST OF SETTLEMENTS  ORGANIZATION
# 17                            BUFFALO SOUTHERN RAILROAD           GPE
# 18                    UNIVERSITY OF TRINIDAD AND TOBAGO  ORGANIZATION
# 19                                        SRIRAM BALAJI        PERSON
# 20                                      CHARLTON HESTON        PERSON
# 21                                            HOT PANTS     TITLEWORK
# 22                        UNITED STATES ARMY UNION ARMY  ORGANIZATION
# 23                           VASCO JOAQUIM ROCHA VIEIRA        PERSON
# 24                                            ORTENBURG           GPE
# 25                                       BRONCO STADIUM  ORGANIZATION
# 26                                        NAVARRO RIVER        PERSON
# 27                                               PAYDAY        PEOPLE
# 28                                          BLOODY MARY        PERSON
# 29                                      PATTI SMITH.JPG        PERSON
# ...                                                 ...           ...
# 1617                                              NEXT1        PERSON
# 1618                                   ANDROMEDA GALAXY        PERSON
# 1619                                      INTERCITY 225  ORGANIZATION
# 1620                                         MONTE COOK        PERSON
# 1621                                   EVESHAM TOWNSHIP           GPE
# 1622                                              OLBIA           GPE
# 1623                                  COUNT OF SOISSONS  ORGANIZATION
# 1624                                        INFORMATION  ORGANIZATION
# 1625                                       CAMERON DIAZ        PERSON
# 1626                                             AUBURN  ORGANIZATION
# 1627                                       HENRI GIRAUD        PERSON
# 1628                   GOVERNMENT SPONSORED ENTERPRISES  ORGANIZATION
# 1629                                       CO OF LONDON  ORGANIZATION
# 1630                                       25PX FLORIDA        PERSON
# 1631                                             ORTRUD           GPE
# 1632                                           DRAWINGS           GPE
# 1633                                    BLAINE ANDERSON        PERSON
# 1634                                          LIGURIANS           GPE
# 1635                                      LEON-CASTILLA        PERSON
# 1636                                      DUDLEY CLARKE        PERSON
# 1637                                          WORLESTON           GPE
# 1638                           COURT OF MILITARY HONOUR  ORGANIZATION
# 1639                                           FRANEKER           GPE
# 1640                                          SPORTSNET  ORGANIZATION
# 1641                                           TRAY DEE  ORGANIZATION
# 1642                                     AMERICAN SOUTH  ORGANIZATION
# 1643                                            BACTRIA           GPE
# 1644                                          KEVIN KOE        PERSON
# 1645                                        SALERNITANA           GPE
# 1646                                        MARY MARTIN        PERSON
#
# [1647 rows x 4 columns]

# %% [markdown]
# ##Dump data to CSV, and then copy over to db2 machine for featurization

# %%
print len(samples_pos)
print len(samples_neg)
# Out:
# 2000
# 1647

# %%
samples_pos['label']=numpy.ones(len(samples_pos))
samples_neg['label']=numpy.ones(len(samples_neg))*(-1)
samples = pandas.concat([samples_pos,samples_neg],ignore_index=True)
#samples

# %%
python_samples_name = 'datarank_samples_frompython.csv'
python_samples_localpath = '/ceph/vinith/kg/'+python_samples_name
samples.to_csv(python_samples_localpath,header=False,index=False)

# %% [markdown]
# ###SCP this over to the DB2 machine

# %%
python_samples_db2machinepath = '/home/db2inst1/vinith/'+python_samples_name
argdict = {'localpath': python_samples_localpath,'output_path':python_samples_db2machinepath}
print "scp %(localpath)s db2inst1@wd-app03.swg.usma.ibm.com:%(output_path)s" % argdict
# Out:
# scp /ceph/vinith/kg/datarank_samples_frompython.csv db2inst1@wd-app03.swg.usma.ibm.com:/home/db2inst1/vinith/datarank_samples_frompython.csv

# %% [markdown]
# ## Generate sql for featurization

# %%
sql_skeleton = open('/ceph/vinith/kg/featurizing_sql/featurize_skeleton.sql','r').read()
featurized_samples_db2machinepath ='/home/db2inst1/vinith/featurized_samples_estats2.del'
print sql_skeleton % {'input_path': python_samples_db2machinepath, 'output_path': featurized_samples_db2machinepath}
# Out:
# --create samples table from samples from python
# drop table linkpred_samples;
# create table linkpred_samples
# 	("s" varchar(128), "st" varchar(128), "o" varchar(128), "ot" varchar(128), "label" int);
# import from /home/db2inst1/vinith/datarank_samples_frompython.csv of del insert into linkpred_samples("s","st","o","ot","label");
#
# --featurize the samples and dump them to disk.
# export to /home/db2inst1/vinith/featurized_samples_estats2.del of del
# SELECT
# 	A_X_B_estatsXA."label" as "label",
# 	A_X_B_estatsXA."A" as "A",
# 	A_X_B_estatsXA."X" as "X",
# 	A_X_B_estatsXA."B" as "B",
# 	A_X_B_estatsXA."At" as "At",
# 	A_X_B_estatsXA."Xt" as "Xt",
# 	A_X_B_estatsXA."Bt" as "Bt",
# 	A_X_B_estatsXA."AX" as "AX",
# 	A_X_B_estatsXA."XB" as "XB",
# 	A_X_B_estatsXA."directionXB",
# 	A_X_B_estatsXA."directionAX",
# 	A_X_B_estatsXA."mAX" as "mAX",
# 	A_X_B_estatsXA."mXB" as "mXB",
# 	A_X_B_estatsXA."docsAX" as "docsAX",
# 	A_X_B_estatsXA."docsXB" as "docsXB",
# 	A_X_B_estatsXA."entity_connections_X"  as "entity_connections_X",
# 	A_X_B_estatsXA."docs_X" as "docs_X",
# 	A_X_B_estatsXA."rm_count_X" as "rm_count_X",
# 	A_X_B_estatsXA."entity_connections_A"  as "entity_connections_A",
# 	A_X_B_estatsXA."docs_A" as "docs_A",
# 	A_X_B_estatsXA."rm_count_A" as "rm_count_A",
# 	estats_all."NUMBEROFDISTINCTRELATEDENTITIES"  as "entity_connections_B",
# 	estats_all."DOCUMENTCOUNT" as "docs_B",
# 	estats_all."RELATIONSHIPMENTIONCOUNT" as "rm_count_B"
# FROM
# 	(SELECT
# 		A_X_B_estatsX."directionXB",
# 		A_X_B_estatsX."directionAX",
# 		A_X_B_estatsX."label" as "label",
# 		A_X_B_estatsX."A" as "A",
# 		A_X_B_estatsX."X" as "X",
# 		A_X_B_estatsX."B" as "B",
# 		A_X_B_estatsX."At" as "At",
# 		A_X_B_estatsX."Xt" as "Xt",
# 		A_X_B_estatsX."Bt" as "Bt",
# 		A_X_B_estatsX."AX" as "AX",
# 		A_X_B_estatsX."XB" as "XB",
# 		A_X_B_estatsX."mAX" as "mAX",
# 		A_X_B_estatsX."mXB" as "mXB",
# 		A_X_B_estatsX."docsAX" as "docsAX",
# 		A_X_B_estatsX."docsXB" as "docsXB",
# 		A_X_B_estatsX."entity_connections_X"  as "entity_connections_X",
# 		A_X_B_estatsX."docs_X" as "docs_X",
# 		A_X_B_estatsX."rm_count_X" as "rm_count_X",
# 		estats_all."NUMBEROFDISTINCTRELATEDENTITIES"  as "entity_connections_A",
# 		estats_all."DOCUMENTCOUNT" as "docs_A",
# 		estats_all."RELATIONSHIPMENTIONCOUNT" as "rm_count_A"
# 	FROM
# 		(SELECT
# 			A_X_B."directionXB",
# 			A_X_B."directionAX",
# 			A_X_B."label" as "label",
# 			A_X_B."A" as "A",
# 			A_X_B."X" as "X",
# 			A_X_B."B" as "B",
# 			A_X_B."At" as "At",
# 			A_X_B."Xt" as "Xt",
# 			A_X_B."Bt" as "Bt",
# 			A_X_B."AX" as "AX",
# 			A_X_B."XB" as "XB",
# 			A_X_B."mAX" as "mAX",
# 			A_X_B."mXB" as "mXB",
# 			A_X_B."docsAX" as "docsAX",
# 			A_X_B."docsXB" as "docsXB",
# 			estats_all."NUMBEROFDISTINCTRELATEDENTITIES"  as "entity_connections_X",
# 			estats_all."DOCUMENTCOUNT" as "docs_X",
# 			estats_all."RELATIONSHIPMENTIONCOUNT" as "rm_count_X"
# 		FROM
# 			(SELECT
# 				A_X."direction" as "directionAX",
# 				X_B."direction" as "directionXB",
# 				A_X."label" as "label",
# 				A_X."A" as "A",
# 				A_X."At" as "At" ,
# 				A_X."potentialX" as "X",
# 				A_X."potentialXt" as "Xt",
# 				A_X."B" as "B",
# 				A_X."Bt" as "Bt",
# 				A_X."potentialAX" as "AX",
# 				X_B."potentialXB" as "XB",
# 				A_X."mcountAX" as "mAX",
# 				A_X."n_docs" as "docsAX",
# 				X_B."mcountXB" as "mXB",
# 				X_B."n_docs" as "docsXB"
# 			FROM
# 				(
# 					SELECT
# 						"label",
# 						1.0 as "direction",
# 						"A",
# 						"At",
# 						"B",
# 						"Bt",
# 						"potentialX",
# 						"potentialXt",
# 						"potentialAX",
# 						SUM("mcountAX_doc") as "mcountAX",
# 						COUNT(*) as "n_docs"
# 					FROM
# 						(SELECT
# 								linkpred_samples."label" as "label",
# 								linkpred_samples."s" as "A",
# 								linkpred_samples."st" as "At",
# 								linkpred_samples."o" as "B",
# 								linkpred_samples."ot" as "Bt",
# 								FULL_TABLE."o" as "potentialX",
# 								FULL_TABLE."ot" as "potentialXt",
# 								FULL_TABLE."p" as "potentialAX",
# 								FULL_TABLE."documentID" as "documentID",
# 								COUNT(*) as "mcountAX_doc"
# 						FROM
# 								linkpred_samples
# 							inner join
# 								(SELECT "subject/instanceName_up" as "s",
# 										"object/instanceName_up" as "o",
# 										"subject/typeType" as "st",
# 										"object/typeType" as "ot",
# 										"relCanonicalName" as "p",
# 										"documentID"
# 								FROM ADS."SIRE1.1"
# 								WHERE "subject/instanceName_up" != "object/instanceName_up"
# 								) as FULL_TABLE
# 							on linkpred_samples."s"=FULL_TABLE."s" and linkpred_samples."st" = FULL_TABLE."st"
# 						GROUP BY (linkpred_samples."label",
# 								  linkpred_samples."s",
# 								  linkpred_samples."o",
# 								  FULL_TABLE."o",
# 								  linkpred_samples."st",
# 								  linkpred_samples."ot",
# 								  FULL_TABLE."ot",
# 								  FULL_TABLE."p",
# 								  FULL_TABLE."documentID")
# 						)
# 					group by ("label","A","At","B","Bt","potentialX","potentialXt","potentialAX")
# 				union
# 					SELECT
# 						"label",
# 						-1.0 as "direction",
# 						"A",
# 						"At",
# 						"B",
# 						"Bt",
# 						"potentialX",
# 						"potentialXt",
# 						"potentialAX",
# 						SUM("mcountAX_doc") as "mcountAX",
# 						COUNT(*) as "n_docs"
# 					FROM
# 						(SELECT
# 								linkpred_samples."label" as "label",
# 								linkpred_samples."s" as "A",
# 								linkpred_samples."st" as "At",
# 								linkpred_samples."o" as "B",
# 								linkpred_samples."ot" as "Bt",
# 								FULL_TABLE."s" as "potentialX",
# 								FULL_TABLE."st" as "potentialXt",
# 								FULL_TABLE."p" as "potentialAX",
# 								FULL_TABLE."documentID" as "documentID",
# 								COUNT(*) as "mcountAX_doc"
# 						FROM
# 							linkpred_samples
# 						inner join
# 							(SELECT "subject/instanceName_up" as "s",
# 									"object/instanceName_up" as "o",
# 									"subject/typeType" as "st",
# 									"object/typeType" as "ot",
# 									"relCanonicalName" as "p",
# 									"documentID"
# 							FROM ADS."SIRE1.1"
# 							WHERE "subject/instanceName_up" != "object/instanceName_up"
# 							) as FULL_TABLE
# 						on linkpred_samples."s"=FULL_TABLE."o" and linkpred_samples."st" = FULL_TABLE."ot"
# 						GROUP BY (linkpred_samples."label",
# 								  linkpred_samples."s",
# 								  linkpred_samples."o",
# 								  FULL_TABLE."s",
# 								  linkpred_samples."st",
# 								  linkpred_samples."ot",
# 								  FULL_TABLE."st",
# 								  FULL_TABLE."p",
# 								  FULL_TABLE."documentID")
# 						) as FANIN_TO_A_DOC
# 					group by ("label","A","At","B","Bt","potentialX","potentialXt","potentialAX")
# 				) as A_X
# 			inner join
# 				(SELECT
# 						1.0 as "direction",
# 						"A",
# 						"At",
# 						"B",
# 						"Bt",
# 						"potentialX",
# 						"potentialXt",
# 						"potentialXB",
# 						SUM("mcountXB_doc") as "mcountXB",
# 						COUNT(*) as "n_docs"
# 					FROM
# 						(SELECT linkpred_samples."s" as "A",
# 								linkpred_samples."st" as "At",
# 								linkpred_samples."o" as "B",
# 								linkpred_samples."ot" as "Bt",
# 								FULL_TABLE."s" as "potentialX",
# 								FULL_TABLE."st" as "potentialXt",
# 								FULL_TABLE."documentID" as "documentID",
# 								FULL_TABLE."p" as "potentialXB",
# 								COUNT(*) as "mcountXB_doc"
# 						FROM
# 							linkpred_samples
# 						inner join
# 							(SELECT "subject/instanceName_up" as "s",
# 									"object/instanceName_up" as "o",
# 									"subject/typeType" as "st",
# 									"object/typeType" as "ot",
# 									"documentID",
# 									"relCanonicalName" as "p"
# 							FROM ADS."SIRE1.1"
# 							WHERE "subject/instanceName_up" != "object/instanceName_up"
# 							) as FULL_TABLE
# 						on linkpred_samples."o"=FULL_TABLE."o" and linkpred_samples."ot" = FULL_TABLE."ot"
# 						GROUP BY (linkpred_samples."s",
# 								  linkpred_samples."o",
# 								  FULL_TABLE."s",
# 								  linkpred_samples."st",
# 								  linkpred_samples."ot",
# 								  FULL_TABLE."st",
# 								  FULL_TABLE."p",
# 								  FULL_TABLE."documentID")
# 						)
# 					group by ("A","At","B","Bt","potentialX","potentialXt","potentialXB")
# 				union
# 					SELECT
# 						-1.0 as "direction",
# 						"A",
# 						"At",
# 						"B",
# 						"Bt",
# 						"potentialX",
# 						"potentialXt",
# 						"potentialXB",
# 						SUM("mcountXB_doc") as "mcountXB",
# 						COUNT(*) as "n_docs"
# 					FROM
# 						(SELECT linkpred_samples."s" as "A",
# 								linkpred_samples."st" as "At",
# 								linkpred_samples."o" as "B",
# 								linkpred_samples."ot" as "Bt",
# 								FULL_TABLE."o" as "potentialX",
# 								FULL_TABLE."ot" as "potentialXt",
# 								FULL_TABLE."documentID" as "documentID",
# 								FULL_TABLE."p" as "potentialXB",
# 								COUNT(*) as "mcountXB_doc"
# 						FROM
# 							linkpred_samples
# 						inner join
# 							(SELECT "subject/instanceName_up" as "s",
# 									"object/instanceName_up" as "o",
# 									"subject/typeType" as "st",
# 									"object/typeType" as "ot",
# 									"documentID",
# 									"relCanonicalName" as "p"
# 							FROM ADS."SIRE1.1"
# 							WHERE "subject/instanceName_up" != "object/instanceName_up"
# 							) as FULL_TABLE
# 						on linkpred_samples."o"=FULL_TABLE."s" and linkpred_samples."ot" = FULL_TABLE."st"
# 						GROUP BY (linkpred_samples."s",
# 								  linkpred_samples."o",
# 								  FULL_TABLE."o",
# 								  linkpred_samples."st",
# 								  linkpred_samples."ot",
# 								  FULL_TABLE."ot",
# 								  FULL_TABLE."p",
# 								  FULL_TABLE."documentID")
# 						)
# 					group by ("A","At","B","Bt","potentialX","potentialXt","potentialXB")
# 				) as X_B
# 			on A_X."potentialX" = X_B."potentialX"
# 				and A_X."A" = X_B."A"
# 				and A_X."B" = X_B."B"
# 				and A_X."potentialXt" = X_B."potentialXt"
# 				and A_X."At" = X_B."At"
# 				and A_X."Bt" = X_B."Bt"
# 			) as A_X_B
# 		inner join
# 			(SELECT * from ADS.ENTITYSTATS2 where "RELTYPE"='all') as estats_all
# 		on A_X_B."X"=estats_all."ENTITYNAME" and A_X_B."Xt" = estats_all."ENTITYTYPE"
# 		) as A_X_B_estatsX
# 	inner join
# 		(SELECT * from	ADS.ENTITYSTATS2 where "RELTYPE"='all') as estats_all
# 	on A_X_B_estatsX."A"=estats_all."ENTITYNAME" and A_X_B_estatsX."At" = estats_all."ENTITYTYPE"
# 	) as A_X_B_estatsXA
# inner join
# 	(SELECT * from	ADS.ENTITYSTATS2 where "RELTYPE"='all') as estats_all
# on A_X_B_estatsXA."B"=estats_all."ENTITYNAME" and A_X_B_estatsXA."Bt" = estats_all."ENTITYTYPE";

# %% [markdown]
# ##SCP results of featurization sql back over to local machine

# %%
featurized_samples_localpath = '/ceph/vinith/kg/featurized_samples_estats2.del'
argdict = {'db2path': featurized_samples_db2machinepath, 'localpath': featurized_samples_localpath}
print "scp db2inst1@wd-app03.swg.usma.ibm.com:%(db2path)s %(localpath)s" %argdict
# Out:
# scp db2inst1@wd-app03.swg.usma.ibm.com:/home/db2inst1/vinith/featurized_samples_estats2.del /ceph/vinith/kg/featurized_samples_estats2.del
